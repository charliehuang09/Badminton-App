# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.load('data/train/imgs/6.npy')
labels = np.load('data/train/labels/6.npy')

# %%
imga = img[0:3]
imgb = img[3:6]
imgc = img[6:9]
print(imga.shape)
print(imgb.shape)
print(imgc.shape)
# Out:
# (3, 640, 360)
# (3, 640, 360)
# (3, 640, 360)

# %%
plt.imshow(imga.swapaxes(0, 2))
plt.colorbar()

# %%
plt.imshow(imgb.swapaxes(0, 2))
plt.colorbar()

# %%
plt.imshow(imgc.swapaxes(0, 2))
plt.colorbar()
