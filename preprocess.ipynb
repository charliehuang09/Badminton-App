# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
img = np.load('data/train/imgs/6.npy')
labels = np.load('data/train/labels/6.npy')

# %%
plt.imshow(labels.swapaxes(0, 1))
plt.colorbar()

# %%
imga = img[0:3]
imgb = img[3:6]
imgc = img[6:9]
print(imga.shape)
print(imgb.shape)
print(imgc.shape)
# Out:
# (3, 640, 360)
# (3, 640, 360)
# (3, 640, 360)

# %%
plt.imshow(imga.swapaxes(0, 2) / 255)
plt.colorbar()

# %%
plt.imshow(imgb.swapaxes(0, 2) / 255)
plt.colorbar()

# %%
plt.imshow(imgc.swapaxes(0, 2) / 255)
plt.colorbar()

# %%
print(len(os.listdir('data/train/imgs')))
print(len(os.listdir('data/valid/imgs')))
# Out:
# 4365
# 1
