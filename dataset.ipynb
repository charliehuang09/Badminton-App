# %%
from torch.utils.data import Dataset
import numpy as np
import os
import torch
from tqdm import tqdm, trange
from typing import Literal
from linetimer import CodeTimer
from dataset import Dataset
import matplotlib.pyplot as plt

# %%
train_dataset = Dataset("train")
valid_dataset = Dataset("valid")

x, y = train_dataset[30]
# Out:
# Length: 1461
# Length: 0

# %%
print(x.shape)
print(y.shape)
# Out:
# torch.Size([3, 640, 360])
# torch.Size([11, 640, 360])

# %%
plt.imshow(x.swapaxes(0, 2))

# %%
img = np.empty((640, 360))
print(y.shape)
for i in range(640):
    for j in range(360):
        img[i][j] = np.argmax(y[:, i, j])
# Out:
# torch.Size([11, 640, 360])

# %%
plt.imshow(img.transpose())
plt.colorbar()
