# %%
import torch
import numpy as np
from tqdm import trange
from tqdm import tqdm, trange
import os
import numpy as np
from torchvision.utils import make_grid
import torch
from torch.utils.tensorboard import SummaryWriter
from model import Unet
import cv2
import matplotlib.pyplot as plt
import random
import config

# %%
img = np.load('data_tennis/train/imgs/0.npy')

# %%
img = img[:3]

# %%
img.shape
# Out:
# (3, 640, 360)

# %%
plt.imshow(img.swapaxes(0, 2))

# %%
img = np.load('data_tennis/train/labels/0.npy')

# %%
plt.imshow(img.swapaxes(0, 1))
