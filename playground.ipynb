# %%
import torch
import numpy as np
from tqdm import trange
from tqdm import tqdm, trange
import os
import numpy as np
from torchvision.utils import make_grid
import torch
from torch.utils.tensorboard import SummaryWriter
from model import Unet
import cv2
import matplotlib.pyplot as plt
import random

# %%
imgs = torch.from_numpy(np.load(f'data/train/labels/{40}.npy'))
plt.imshow(imgs)

# %%
img = torch.from_numpy(np.load(f'data/train/imgs/{40}.npy').transpose())
plt.imshow(img)

# %%
imgs.max()
# Out:
# tensor(0.0016)

# %%
from torch import nn
import torch
softmax = nn.Softmax2d()

# %%
array = torch.randn(16, 1, 4, 4)

# %%
array[0, 0].sum()
# Out:
# tensor(2.6391)

# %%
array[0, 0].shape
# Out:
# torch.Size([4, 4])

# %%
array = softmax(array)

# %%
array[0, 0].sum()
# Out:
# tensor(16.)

# %%
array[0, 0].shape
# Out:
# torch.Size([4, 4])
